# %% [markdown]
# ### Requisiti
# Per eseguire correttamente il contenuto di questo notebook è consigliabile
# - una macchina con sistema operativo Linux o Windows con WSL abilitato (prefiribilmente Ubuntu)
# - memoria RAM uguale o superiore a 8 GB
# - installare le dipendenze python specificate in requirements e usare un ambiente virtuale python

# %%
import pandas as pd
import turicreate as tc
from gensim.models import KeyedVectors

"""
    Data imports
"""
u_cols = ['user_id', 'age', 'sex', 'occupation', 'zip_code']
users = pd.read_csv('data/ml-100k/u.user', sep='|', names=u_cols, encoding='latin-1')
r_cols = ['user_id', 'movie_id', 'rating', 'unix_timestamp']
ratings = pd.read_csv('data/ml-100k/u.data', sep='\t', names=r_cols, encoding='latin-1')

# %%
frame.print_rows(num_rows=10)
# Out:
# +---------+----------+--------+----------------+
# | user_id | movie_id | rating | unix_timestamp |
# +---------+----------+--------+----------------+
# |   196   |   242    |   3    |   881250949    |
# |   186   |   302    |   3    |   891717742    |
# |    22   |   377    |   1    |   878887116    |
# |   244   |    51    |   2    |   880606923    |
# |   166   |   346    |   1    |   886397596    |
# |   298   |   474    |   4    |   884182806    |
# |   115   |   265    |   2    |   881171488    |
# |   253   |   465    |   5    |   891628467    |
# |   305   |   451    |   3    |   886324817    |
# |    6    |    86    |   3    |   883603013    |
# +---------+----------+--------+----------------+
# [100000 rows x 4 columns]

# %% [markdown]
# ## Entity Liniking
#
# Il riconoscimento di entita in un testo è una operazione ben conosciuta nell'ambito del Natural Language Processing e più recentemente ha subito nuovi sviluppi grazie alla disponibilità di basi di conoscenza liberamente disponibili sul web.
# L'obiettivo principale di un sistema di EL è disambiguare la menzione di una entità $e$ appartenente ad una base di conoscenza $KB$ nel suo contesto.
#
# Per poter poter estrarre le embeddings delle entità presenti occorre effettuare la mappattura dei film del dataset MovieLens con gli uri presenti nell'ontologia DBpedia. Per tale scopo si può utilizzare il tool DBPedia Lookup (query SPARQL, keyword index, ordinamento Wikipedia in-links)  ma per accorciare i tempi utilizziamo una mappattura già elaborata e disponibile online effettuata perè con uno snapshot di DBpedia del 2016.
#
# **Riferimenti**
# - [SPRank: Semantic Path-based Ranking for Top-N Recommendations using Linked Open Data](https://sisinflab.poliba.it/publications/2016/DOTD16/SPRank%20Semantic%20Path-based%20Ranking%20for%20Top-N%20Recommendations%20using%20Linked%20Open%20Data%20-%20ACM%20TIST%202016.pdf)
# - [DBPedia Lookup](https://github.com/dbpedia/lookup/)
# - [LODrecsys-datasets](https://github.com/sisinflab/LODrecsys-datasets/)
# - [Movie-RS](https://github.com/voitijaner/Movie-RSs-Master-Thesis-Submission-Voit)

# %%
# !wget https://raw.githubusercontent.com/sisinflab/LODrecsys-datasets/master/Movielens1M/MappingMovielens2DBpedia-1.2.tsv -O data/LODrecsys/mappings.tsv

# %% [markdown]
# ### Generating embeddings example

# %%
from pyrdf2vec import RDF2VecTransformer
from pyrdf2vec.graphs import KG
from pyrdf2vec.embedders import Word2Vec
from pyrdf2vec.walkers import (
    AnonymousWalker,
    CommunityWalker,
    HALKWalker,
    NGramWalker,
    RandomWalker,
    WalkletWalker,
    WLWalker, # Weisfeiler-Lehman
)
from pyrdf2vec.samplers import (
    ObjPredFreqSampler,
    PredFreqSampler,
    UniformSampler,
    ObjFreqSampler,
    PageRankSampler,
)

kg = KG("https://dbpedia.org/sparql/")
# RandomWalks[depth = 4, walks_per_graph = 500], word2vec[embedding_size=200, mode=Skip-Gram]
uris = [] # uris
depth = 4
walks_per_graph = 500
random_walker = RandomWalker(depth, walks_per_graph, n_jobs=6) #  n_jobs should be adapted according to the number of cores available
transformer = RDF2VecTransformer(walkers=[random_walker], embedder=Word2Vec(size=200, sg=1), verbose=2) # sg = {0 => CBOW, 1 => SGRAM}
embeddings, literals = transformer.fit_transform(kg, uris)
transformer.save("movielens1M-dpbedia-model")

# %% [markdown]
# ### Pretrained RDF2Vec Emmbeddings
# L'addestramento di RDF2Vec può richiedere abbastanza tempo e non è stato dunque possibile in questa occassione effettuare il training e effettuare un tunning dei parametri come la dimensione degli embeddings, la profondità delle camminare e la strategie di embedding di word2vec (CBOW e Skip-Gram). Però sono disponibili vari modelli già addestrati con diversi parametri su [kgvec2go](http://kgvec2go.org/download.html).
# I parametri scelti, tra quelli disponibili, per questo task sono tratti da [RDF2Vec: RDF Graph Embeddings and Their Applications](https://sisinflab.poliba.it/publications/2018/RRDDP18b/RDF2Vec-RDF-Graph-Embeddings-and-Their-Applications.pdf)

# %%
# DBpedia 2021-09 500 walks, depth: 4, SG, 200 dimensions
# !wget http://data.dws.informatik.uni-mannheim.de/kgvec2go/dbpedia/2021-09/classic-rdf2vec-sg-200/model.kv -O data/dbpedia/model.kv
# !wget http://data.dws.informatik.uni-mannheim.de/kgvec2go/dbpedia/2021-09/classic-rdf2vec-sg-200/model.kv.vectors.npy -O data/dbpedia/model.kv.vectors.npy

# %%
vectors = KeyedVectors.load('data/dbpedia/model.kv')

# %%
mappings = pd.read_csv('data/LODrecsys/mappings.tsv', sep='\t', header = 0, names=["movie_id", "movie_name", "movie_uri"])
uris = [uri for uri in df["movie_uri"] if vectors.__contains__(uri)]

mappings = mappings[mappings.apply(lambda x: vectors.__contains__(x["movie_uri"]), axis=1)]
mappings.head()
# Out:
#    movie_id                 movie_name  \
# 0      1799       Suicide Kings (1997)
# 1       521   Romeo Is Bleeding (1993)
# 2      3596             Screwed (2000)
# 3      3682        Magnum Force (1973)
# 4      2635  Mummy's Curse, The (1944)
#
#                                          movie_uri
# 0        http://dbpedia.org/resource/Suicide_Kings
# 1    http://dbpedia.org/resource/Romeo_Is_Bleeding
# 2  http://dbpedia.org/resource/Screwed_(2000_film)
# 3         http://dbpedia.org/resource/Magnum_Force
# 4    http://dbpedia.org/resource/The_Mummy's_Curse

# %%
dbpedia = pd.DataFrame([vectors[uri] for uri in uris])
dbpedia.insert(loc=0, column='movie_id', value=list(mappings["movie_id"]))
dbpedia.head()
# Out:
#    movie_id         0         1         2         3         4         5  \
# 0      1799  0.104363 -0.030366  0.024397  0.011784  0.074084 -0.009074
# 1       521  0.483485 -0.238453 -0.214155 -0.149148  0.374526 -0.263988
# 2      3596  0.038226 -0.022396 -0.189044  0.024776  0.499730 -0.102583
# 3      3682 -0.132794 -0.716965 -0.296625 -0.064314  0.312275 -0.356286
# 4      2635  0.186714  0.010445 -0.553984  0.019468  0.908595 -0.361530
#
#           6         7         8  ...       190       191       192       193  \
# 0  0.028095 -0.009043  0.032457  ...  0.061471 -0.042182  0.076538  0.005617
# 1 -0.193399 -0.581973 -0.548007  ...  0.561658 -0.298676 -0.075646  0.285023
# 2 -0.520485 -0.944271  0.880034  ...  0.790360  0.063050  0.331688  0.235169
# 3 -0.392580 -0.581087  0.227907  ...  0.460223  0.149874 -0.045281  0.380723
# 4  0.011017 -0.416185  0.319215  ...  0.443430  0.357368  0.396677  0.371717
#
#         194       195       196       197       198       199
# 0  0.068206 -0.091303 -0.021942 -0.035422  0.027923  0.011205
# 1  0.056442 -0.493393 -0.566069 -0.659976 -0.472822  0.000019
# 2 -0.021070 -0.379494 -0.176780 -0.252495  0.529196  0.050202
# 3 -0.158305 -0.814315 -0.640020 -0.270090  0.297235 -0.442252
# 4  0.056948 -0.438682 -0.347058 -0.451110  0.106972  0.116729
#
# [5 rows x 201 columns]

# %%
ratings = ratings[ratings["movie_id"].isin(mappings["movie_id"])]
ratings.head()
# Out:
#    user_id  movie_id  rating  unix_timestamp
# 0      196       242       3       881250949
# 2       22       377       1       878887116
# 4      166       346       1       886397596
# 5      298       474       4       884182806
# 6      115       265       2       881171488

# %%
ratings_frame = tc.SFrame(ratings)
item_frame =tc.SFrame(dbpedia)
# ~ 80/20 split
train_data, test_data = tc.recommender.util.random_split_by_user(ratings_frame, user_id="user_id", item_id="movie_id")
train_data2 = train_data.copy()
train_data3 = train_data.copy()

rfm_with_rdf = tc.recommender.ranking_factorization_recommender.create(train_data, user_id="user_id", item_id="movie_id", target='rating', item_data=item_frame)
rfm = tc.recommender.ranking_factorization_recommender.create(train_data2, user_id="user_id", item_id="movie_id", target='rating')
itemknn = tc.recommender.item_similarity_recommender.create(train_data3,  user_id="user_id", item_id="movie_id", similarity_type="cosine")
# rfm_with_rdf_recommendations = rfm_with_rdf.recommend()
# rfm = rfm.recommend()

# %%
comparing = tc.recommender.util.compare_models(test_data, [rfm_with_rdf, rfm, itemknn], model_names=["Ranking FM with RDF2Vec embs", "Ranking FM", "ItemKnn"], metric='rmse')
# 1.0273390850597666, 1.1255684868360116

# %%
print(rfm_with_rdf_recommendations)

# %%
print(rfm)

# %%
for c in comparing:
    print(c)

# %%
def evaluate(test_data, threshold=3.5, est):
    tp = 0
    fn = 0
    fp = 0
    tn = 0
    test_data_pandas = test_data.to_dataframe()
    for row in test_data_pandas.iterrows():
        row["user_id"]
        row["movie_id"]
        if row["rating"] >= threshold:
            if est(row["user_id"], row["user_id"]) >= threshold:
                tp += 1
            else:
                fn += 1
        elif est(row["user_id"], row["user_id"]) >= threshold:
            fp += 1
        else:
            tn += 1
    precision = tp / (tp + fp)
    recall = tp / (tp + fn)
    f1 = 2 * (precision * recall) / (precision + recall)

    return precision, recall, f1
# Out:
# (0, user_id                 196
# movie_id                242
# rating                    3
# unix_timestamp    881250949
# Name: 0, dtype: int64)
# (1, user_id                  22
# movie_id                377
# rating                    1
# unix_timestamp    878887116
# Name: 1, dtype: int64)
# (2, user_id                 298
# movie_id                474
# rating                    4
# unix_timestamp    884182806
# Name: 2, dtype: int64)
# (3, user_id                 253
# movie_id                465
# rating                    5
# unix_timestamp    891628467
# Name: 3, dtype: int64)
# (4, user_id                  62
# movie_id                257
# rating                    2
# unix_timestamp    879372434
# Name: 4, dtype: int64)
# (5, user_id                 210
# movie_id                 40
# rating                    3
# unix_timestamp    891035994
# Name: 5, dtype: int64)
# (6, user_id                 119
# movie_id                392
# rating                    4
# unix_timestamp    886176814
# Name: 6, dtype: int64)
# (7, user_id                 167
# movie_id                486
# rating                    4
# unix_timestamp    892738452
# Name: 7, dtype: int64)
# (8, user_id                 291
# movie_id                118
# rating                    2
# unix_timestamp    874833878
# Name: 8, dtype: int64)
# (9, user_id                  50
# movie_id                246
# rating                    3
# unix_timestamp    877052329
# Name: 9, dtype: int64)
# (10, user_id                 290
# movie_id                 88
# rating                    4
# unix_timestamp    880731963
# Name: 10, dtype: int64)
# (11, user_id                   7
# movie_id                 32
# rating                    4
# unix_timestamp    891350932
# Name: 11, dtype: int64)
# (12, user_id                  99
# movie_id                  4
# rating                    5
# unix_timestamp    886519097
# Name: 12, dtype: int64)
# (13, user_id                  72
# movie_id                679
# rating                    2
# unix_timestamp    880037164
# Name: 13, dtype: int64)
# (14, user_id                 290
# movie_id                143
# rating                    5
# unix_timestamp    880474293
# Name: 14, dtype: int64)
# (15, user_id                  60
# movie_id                427
# rating                    5
# unix_timestamp    883326620
# Name: 15, dtype: int64)
# (16, user_id                 127
# movie_id                229
# rating                    5
# unix_timestamp    884364867
# Name: 16, dtype: int64)
# (17, user_id                 299
# movie_id                229
# rating                    3
# unix_timestamp    878192429
# Name: 17, dtype: int64)
# (18, user_id                 276
# movie_id                 54
# rating                    3
# unix_timestamp    874791025
# Name: 18, dtype: int64)
# (19, user_id                 222
# movie_id                366
# rating                    4
# unix_timestamp    878183381
# Name: 19, dtype: int64)
# (20, user_id                  11
# movie_id                111
# rating                    4
# unix_timestamp    891903862
# Name: 20, dtype: int64)
# (21, user_id                  28
# movie_id                209
# rating                    4
# unix_timestamp    881961214
# Name: 21, dtype: int64)
# (22, user_id                 293
# movie_id                685
# rating                    3
# unix_timestamp    888905170
# Name: 22, dtype: int64)
# (23, user_id                 166
# movie_id                328
# rating                    5
# unix_timestamp    886397722
# Name: 23, dtype: int64)
# (24, user_id                 271
# movie_id                132
# rating                    5
# unix_timestamp    885848672
# Name: 24, dtype: int64)
# (25, user_id                  44
# movie_id                195
# rating                    5
# unix_timestamp    878347874
# Name: 25, dtype: int64)
# (26, user_id                 194
# movie_id                385
# rating                    2
# unix_timestamp    879524643
# Name: 26, dtype: int64)
# (27, user_id                 222
# movie_id                750
# rating                    5
# unix_timestamp    883815120
# Name: 27, dtype: int64)
# (28, user_id                 262
# movie_id               1147
# rating                    4
# unix_timestamp    879791710
# Name: 28, dtype: int64)
# (29, user_id                 174
# movie_id                368
# rating                    1
# unix_timestamp    886434402
# Name: 29, dtype: int64)
# (30, user_id                 299
# movie_id                955
# rating                    4
# unix_timestamp    889502823
# Name: 30, dtype: int64)
# (31, user_id                 160
# movie_id                135
# rating                    4
# unix_timestamp    876860807
# Name: 31, dtype: int64)
# (32, user_id                  85
# movie_id                427
# rating                    3
# unix_timestamp    879456350
# Name: 32, dtype: int64)
# (33, user_id                 279
# movie_id               1240
# rating                    1
# unix_timestamp    892174404
# Name: 33, dtype: int64)
# (34, user_id                  26
# movie_id                930
# rating                    2
# unix_timestamp    891385985
# Name: 34, dtype: int64)
# (35, user_id                  92
# movie_id               1079
# rating                    3
# unix_timestamp    886443455
# Name: 35, dtype: int64)
# (36, user_id                 125
# movie_id                235
# rating                    2
# unix_timestamp    892838559
# Name: 36, dtype: int64)
# (37, user_id                  87
# movie_id                554
# rating                    4
# unix_timestamp    879875940
# Name: 37, dtype: int64)
# (38, user_id                 301
# movie_id                401
# rating                    4
# unix_timestamp    882078040
# Name: 38, dtype: int64)
# (39, user_id                  70
# movie_id                746
# rating                    3
# unix_timestamp    884150257
# Name: 39, dtype: int64)
# (40, user_id                 233
# movie_id                202
# rating                    5
# unix_timestamp    879394264
# Name: 40, dtype: int64)
# (41, user_id                 192
# movie_id                476
# rating                    2
# unix_timestamp    881368243
# Name: 41, dtype: int64)
# (42, user_id                  83
# movie_id                576
# rating                    4
# unix_timestamp    880308755
# Name: 42, dtype: int64)
# (43, user_id                   7
# movie_id                382
# rating                    4
# unix_timestamp    891352093
# Name: 43, dtype: int64)
# (44, user_id                 286
# movie_id                143
# rating                    4
# unix_timestamp    889651549
# Name: 44, dtype: int64)
# (45, user_id                 113
# movie_id                595
# rating                    5
# unix_timestamp    875936424
# Name: 45, dtype: int64)
# (46, user_id                 189
# movie_id                520
# rating                    5
# unix_timestamp    893265380
# Name: 46, dtype: int64)
# (47, user_id                 158
# movie_id                177
# rating                    4
# unix_timestamp    880134407
# Name: 47, dtype: int64)
# (48, user_id                 302
# movie_id                322
# rating                    2
# unix_timestamp    879436875
# Name: 48, dtype: int64)
# (49, user_id                  13
# movie_id                198
# rating                    3
# unix_timestamp    881515193
# Name: 49, dtype: int64)
# (50, user_id                 145
# movie_id                237
# rating                    5
# unix_timestamp    875270570
# Name: 50, dtype: int64)
# (51, user_id                 201
# movie_id                767
# rating                    4
# unix_timestamp    884114505
# Name: 51, dtype: int64)
# (52, user_id                  95
# movie_id                135
# rating                    3
# unix_timestamp    879197562
# Name: 52, dtype: int64)
# (53, user_id                 187
# movie_id                 64
# rating                    5
# unix_timestamp    879465631
# Name: 53, dtype: int64)
# (54, user_id                 170
# movie_id                749
# rating                    5
# unix_timestamp    887646170
# Name: 54, dtype: int64)
# (55, user_id                 184
# movie_id                153
# rating                    3
# unix_timestamp    889911285
# Name: 55, dtype: int64)
# (56, user_id                   1
# movie_id                160
# rating                    4
# unix_timestamp    875072547
# Name: 56, dtype: int64)
# (57, user_id                 301
# movie_id                191
# rating                    3
# unix_timestamp    882075672
# Name: 57, dtype: int64)
# (58, user_id                 254
# movie_id                662
# rating                    4
# unix_timestamp    887347350
# Name: 58, dtype: int64)
# (59, user_id                  94
# movie_id               1224
# rating                    3
# unix_timestamp    891722802
# Name: 59, dtype: int64)
# (60, user_id                 197
# movie_id                 96
# rating                    5
# unix_timestamp    891409839
# Name: 60, dtype: int64)
# (61, user_id                 180
# movie_id                462
# rating                    5
# unix_timestamp    877544218
# Name: 61, dtype: int64)
# (62, user_id                   7
# movie_id                163
# rating                    4
# unix_timestamp    891353444
# Name: 62, dtype: int64)
# (63, user_id                  52
# movie_id                250
# rating                    3
# unix_timestamp    882922661
# Name: 63, dtype: int64)
# (64, user_id                  83
# movie_id                 78
# rating                    2
# unix_timestamp    880309089
# Name: 64, dtype: int64)
# (65, user_id                 254
# movie_id                436
# rating                    2
# unix_timestamp    886474216
# Name: 65, dtype: int64)
# (66, user_id                 249
# movie_id                188
# rating                    4
# unix_timestamp    879641067
# Name: 66, dtype: int64)
# (67, user_id                  64
# movie_id                392
# rating                    3
# unix_timestamp    889737542
# Name: 67, dtype: int64)
# (68, user_id                 125
# movie_id                163
# rating                    5
# unix_timestamp    879454956
# Name: 68, dtype: int64)
# (69, user_id                 114
# movie_id                505
# rating                    3
# unix_timestamp    881260203
# Name: 69, dtype: int64)
# (70, user_id                  23
# movie_id                196
# rating                    2
# unix_timestamp    874786926
# Name: 70, dtype: int64)
# (71, user_id                 250
# movie_id                238
# rating                    4
# unix_timestamp    878089963
# Name: 71, dtype: int64)
# (72, user_id                 181
# movie_id                325
# rating                    2
# unix_timestamp    878961814
# Name: 72, dtype: int64)
# (73, user_id                  13
# movie_id                892
# rating                    3
# unix_timestamp    882774224
# Name: 73, dtype: int64)
# (74, user_id                 213
# movie_id                176
# rating                    4
# unix_timestamp    878956338
# Name: 74, dtype: int64)
# (75, user_id                 117
# movie_id               1047
# rating                    2
# unix_timestamp    881009697
# Name: 75, dtype: int64)
# (76, user_id                  85
# movie_id                259
# rating                    2
# unix_timestamp    881705026
# Name: 76, dtype: int64)
# (77, user_id                 137
# movie_id                144
# rating                    5
# unix_timestamp    881433689
# Name: 77, dtype: int64)
# (78, user_id                 189
# movie_id               1060
# rating                    5
# unix_timestamp    893264301
# Name: 78, dtype: int64)
# (79, user_id                 269
# movie_id                246
# rating                    5
# unix_timestamp    891457067
# Name: 79, dtype: int64)
# (80, user_id                 299
# movie_id                303
# rating                    3
# unix_timestamp    877618584
# Name: 80, dtype: int64)
# (81, user_id                 200
# movie_id                365
# rating                    5
# unix_timestamp    884129962
# Name: 81, dtype: int64)
# (82, user_id                 235
# movie_id                185
# rating                    4
# unix_timestamp    889655435
# Name: 82, dtype: int64)
# (83, user_id                 303
# movie_id                200
# rating                    4
# unix_timestamp    879468459
# Name: 83, dtype: int64)
# (84, user_id                  72
# movie_id                 54
# rating                    3
# unix_timestamp    880036854
# Name: 84, dtype: int64)
# (85, user_id                 193
# movie_id                869
# rating                    3
# unix_timestamp    889127811
# Name: 85, dtype: int64)
# (86, user_id                 281
# movie_id                338
# rating                    2
# unix_timestamp    881200457
# Name: 86, dtype: int64)
# (87, user_id                  94
# movie_id                720
# rating                    1
# unix_timestamp    891723593
# Name: 87, dtype: int64)
# (88, user_id                  10
# movie_id                611
# rating                    5
# unix_timestamp    877886722
# Name: 88, dtype: int64)
# (89, user_id                 131
# movie_id                126
# rating                    4
# unix_timestamp    883681514
# Name: 89, dtype: int64)
# (90, user_id                 109
# movie_id                  8
# rating                    3
# unix_timestamp    880572642
# Name: 90, dtype: int64)
# (91, user_id                 234
# movie_id                448
# rating                    3
# unix_timestamp    892335501
# Name: 91, dtype: int64)
# (92, user_id                 288
# movie_id                132
# rating                    3
# unix_timestamp    886374129
# Name: 92, dtype: int64)
# (93, user_id                 301
# movie_id                 33
# rating                    4
# unix_timestamp    882078228
# Name: 93, dtype: int64)
# (94, user_id                 308
# movie_id                 55
# rating                    3
# unix_timestamp    887738760
# Name: 94, dtype: int64)
# (95, user_id                  82
# movie_id                508
# rating                    2
# unix_timestamp    884714249
# Name: 95, dtype: int64)
# (96, user_id                 138
# movie_id                484
# rating                    4
# unix_timestamp    879024127
# Name: 96, dtype: int64)
# (97, user_id                 307
# movie_id                 94
# rating                    3
# unix_timestamp    877122695
# Name: 97, dtype: int64)
# (98, user_id                  10
# movie_id                  7
# rating                    4
# unix_timestamp    877892210
# Name: 98, dtype: int64)
# (99, user_id                  62
# movie_id               1016
# rating                    4
# unix_timestamp    879373008
# Name: 99, dtype: int64)
# (100, user_id                 214
# movie_id                478
# rating                    4
# unix_timestamp    891544052
# Name: 100, dtype: int64)
# (101, user_id                 244
# movie_id                381
# rating                    4
# unix_timestamp    880604077
# Name: 101, dtype: int64)
# (102, user_id                 178
# movie_id                742
# rating                    3
# unix_timestamp    882823833
# Name: 102, dtype: int64)
# (103, user_id                 246
# movie_id                409
# rating                    2
# unix_timestamp    884923372
# Name: 103, dtype: int64)
# (104, user_id                  90
# movie_id               1198
# rating                    5
# unix_timestamp    891383866
# Name: 104, dtype: int64)
# (105, user_id                 222
# movie_id                 49
# rating                    3
# unix_timestamp    878183512
# Name: 105, dtype: int64)
# (106, user_id                   2
# movie_id                292
# rating                    4
# unix_timestamp    888550774
# Name: 106, dtype: int64)
# (107, user_id                  94
# movie_id               1220
# rating                    3
# unix_timestamp    891722678
# Name: 107, dtype: int64)
# (108, user_id                 192
# movie_id                948
# rating                    3
# unix_timestamp    881368302
# Name: 108, dtype: int64)
# (109, user_id                  85
# movie_id                588
# rating                    3
# unix_timestamp    880838306
# Name: 109, dtype: int64)
# (110, user_id                 201
# movie_id               1100
# rating                    4
# unix_timestamp    884112800
# Name: 110, dtype: int64)
# (111, user_id                 158
# movie_id                665
# rating                    2
# unix_timestamp    880134532
# Name: 111, dtype: int64)
# (112, user_id                 217
# movie_id                  2
# rating                    3
# unix_timestamp    889069782
# Name: 112, dtype: int64)
# (113, user_id                 222
# movie_id                796
# rating                    4
# unix_timestamp    878183684
# Name: 113, dtype: int64)
# (114, user_id                 267
# movie_id                121
# rating                    3
# unix_timestamp    878970681
# Name: 114, dtype: int64)
# (115, user_id                 268
# movie_id                 21
# rating                    3
# unix_timestamp    875742822
# Name: 115, dtype: int64)
# (116, user_id                 234
# movie_id                 81
# rating                    3
# unix_timestamp    892334680
# Name: 116, dtype: int64)
# (117, user_id                 156
# movie_id                661
# rating                    4
# unix_timestamp    888185947
# Name: 117, dtype: int64)
# (118, user_id                 235
# movie_id                230
# rating                    4
# unix_timestamp    889655162
# Name: 118, dtype: int64)
# (119, user_id                  77
# movie_id                172
# rating                    3
# unix_timestamp    884752562
# Name: 119, dtype: int64)
# (120, user_id                  49
# movie_id               1003
# rating                    2
# unix_timestamp    888068651
# Name: 120, dtype: int64)
# (121, user_id                  42
# movie_id               1028
# rating                    4
# unix_timestamp    881106072
# Name: 121, dtype: int64)
# (122, user_id                 197
# movie_id                688
# rating                    1
# unix_timestamp    891409564
# Name: 122, dtype: int64)
# (123, user_id                  90
# movie_id                258
# rating                    3
# unix_timestamp    891382121
# Name: 123, dtype: int64)
# (124, user_id                 295
# movie_id                190
# rating                    4
# unix_timestamp    879517062
# Name: 124, dtype: int64)
# (125, user_id                 221
# movie_id               1010
# rating                    3
# unix_timestamp    875246662
# Name: 125, dtype: int64)
# (126, user_id                 207
# movie_id                318
# rating                    5
# unix_timestamp    877124871
# Name: 126, dtype: int64)
# (127, user_id                   7
# movie_id                648
# rating                    5
# unix_timestamp    891351653
# Name: 127, dtype: int64)
# (128, user_id                  94
# movie_id                 62
# rating                    3
# unix_timestamp    891722933
# Name: 128, dtype: int64)
# (129, user_id                 230
# movie_id                304
# rating                    5
# unix_timestamp    880484286
# Name: 129, dtype: int64)
# (130, user_id                 311
# movie_id                179
# rating                    2
# unix_timestamp    884365357
# Name: 130, dtype: int64)
# (131, user_id                  59
# movie_id                 92
# rating                    5
# unix_timestamp    888204997
# Name: 131, dtype: int64)
# (132, user_id                 113
# movie_id                126
# rating                    5
# unix_timestamp    875076827
# Name: 132, dtype: int64)
# (133, user_id                 255
# movie_id               1034
# rating                    1
# unix_timestamp    883217030
# Name: 133, dtype: int64)
# (134, user_id                   6
# movie_id                463
# rating                    4
# unix_timestamp    883601713
# Name: 134, dtype: int64)
# (135, user_id                 286
# movie_id                298
# rating                    4
# unix_timestamp    875807004
# Name: 135, dtype: int64)
# (136, user_id                 111
# movie_id                301
# rating                    4
# unix_timestamp    891680028
# Name: 136, dtype: int64)
# (137, user_id                  25
# movie_id                222
# rating                    4
# unix_timestamp    885852817
# Name: 137, dtype: int64)
# (138, user_id                  83
# movie_id                215
# rating                    4
# unix_timestamp    880307940
# Name: 138, dtype: int64)
# (139, user_id                  89
# movie_id                216
# rating                    5
# unix_timestamp    879459859
# Name: 139, dtype: int64)
# (140, user_id                 140
# movie_id                332
# rating                    3
# unix_timestamp    879013617
# Name: 140, dtype: int64)
# (141, user_id                 201
# movie_id                203
# rating                    5
# unix_timestamp    884114471
# Name: 141, dtype: int64)
# (142, user_id                 126
# movie_id                245
# rating                    3
# unix_timestamp    887854726
# Name: 142, dtype: int64)
# (143, user_id                 181
# movie_id                930
# rating                    1
# unix_timestamp    878963275
# Name: 143, dtype: int64)
# (144, user_id                  85
# movie_id               1065
# rating                    3
# unix_timestamp    879455021
# Name: 144, dtype: int64)
# (145, user_id                 275
# movie_id                186
# rating                    3
# unix_timestamp    880314383
# Name: 145, dtype: int64)
# (146, user_id                  68
# movie_id                742
# rating                    1
# unix_timestamp    876974198
# Name: 146, dtype: int64)
# (147, user_id                 160
# movie_id                462
# rating                    4
# unix_timestamp    876858346
# Name: 147, dtype: int64)
# (148, user_id                  72
# movie_id                568
# rating                    4
# unix_timestamp    880037203
# Name: 148, dtype: int64)
# (149, user_id                  83
# movie_id                281
# rating                    5
# unix_timestamp    880307072
# Name: 149, dtype: int64)
# (150, user_id                 222
# movie_id                 53
# rating                    5
# unix_timestamp    878184113
# Name: 150, dtype: int64)
# (151, user_id                 308
# movie_id               1286
# rating                    3
# unix_timestamp    887738151
# Name: 151, dtype: int64)
# (152, user_id                 313
# movie_id                117
# rating                    4
# unix_timestamp    891015319
# Name: 152, dtype: int64)
# (153, user_id                  21
# movie_id                164
# rating                    5
# unix_timestamp    874951695
# Name: 153, dtype: int64)
# (154, user_id                  73
# movie_id                206
# rating                    3
# unix_timestamp    888625754
# Name: 154, dtype: int64)
# (155, user_id                 239
# movie_id                513
# rating                    5
# unix_timestamp    889178887
# Name: 155, dtype: int64)
# (156, user_id                 233
# movie_id                375
# rating                    4
# unix_timestamp    876374419
# Name: 156, dtype: int64)
# (157, user_id                  13
# movie_id                418
# rating                    2
# unix_timestamp    882398763
# Name: 157, dtype: int64)
# (158, user_id                  13
# movie_id                858
# rating                    1
# unix_timestamp    882397068
# Name: 158, dtype: int64)
# (159, user_id                  13
# movie_id                 72
# rating                    4
# unix_timestamp    882141727
# Name: 159, dtype: int64)
# (160, user_id                  59
# movie_id                485
# rating                    2
# unix_timestamp    888204466
# Name: 160, dtype: int64)
# (161, user_id                  62
# movie_id                182
# rating                    5
# unix_timestamp    879375169
# Name: 161, dtype: int64)
# (162, user_id                  65
# movie_id                125
# rating                    4
# unix_timestamp    879217509
# Name: 162, dtype: int64)
# (163, user_id                 249
# movie_id                239
# rating                    3
# unix_timestamp    879572284
# Name: 163, dtype: int64)
# (164, user_id                  84
# movie_id                121
# rating                    4
# unix_timestamp    883452307
# Name: 164, dtype: int64)
# (165, user_id                 135
# movie_id               1046
# rating                    3
# unix_timestamp    879858003
# Name: 165, dtype: int64)
# (166, user_id                 301
# movie_id                523
# rating                    4
# unix_timestamp    882076146
# Name: 166, dtype: int64)
# (167, user_id                  24
# movie_id                191
# rating                    5
# unix_timestamp    875323003
# Name: 167, dtype: int64)
# (168, user_id                 307
# movie_id                634
# rating                    3
# unix_timestamp    879283385
# Name: 168, dtype: int64)
# (169, user_id                 207
# movie_id                 68
# rating                    2
# unix_timestamp    877125350
# Name: 169, dtype: int64)
# (170, user_id                 291
# movie_id                418
# rating                    4
# unix_timestamp    875086920
# Name: 170, dtype: int64)
# (171, user_id                 293
# movie_id                380
# rating                    2
# unix_timestamp    888907527
# Name: 171, dtype: int64)
# (172, user_id                 312
# movie_id                692
# rating                    4
# unix_timestamp    891699426
# Name: 172, dtype: int64)
# (173, user_id                 276
# movie_id                419
# rating                    5
# unix_timestamp    874792907
# Name: 173, dtype: int64)
# (174, user_id                 279
# movie_id                168
# rating                    5
# unix_timestamp    875296435
# Name: 174, dtype: int64)
# (175, user_id                 303
# movie_id                393
# rating                    4
# unix_timestamp    879484981
# Name: 175, dtype: int64)
# (176, user_id                  94
# movie_id                792
# rating                    4
# unix_timestamp    885873006
# Name: 176, dtype: int64)
# (177, user_id                 196
# movie_id                381
# rating                    4
# unix_timestamp    881251728
# Name: 177, dtype: int64)
# (178, user_id                 308
# movie_id                436
# rating                    4
# unix_timestamp    887739257
# Name: 178, dtype: int64)
# (179, user_id                 181
# movie_id                 14
# rating                    1
# unix_timestamp    878962392
# Name: 179, dtype: int64)
# (180, user_id                 202
# movie_id                283
# rating                    3
# unix_timestamp    879727153
# Name: 180, dtype: int64)
# (181, user_id                 184
# movie_id                602
# rating                    4
# unix_timestamp    889909691
# Name: 181, dtype: int64)
# (182, user_id                 313
# movie_id                436
# rating                    4
# unix_timestamp    891029877
# Name: 182, dtype: int64)
# (183, user_id                 130
# movie_id                569
# rating                    3
# unix_timestamp    880396494
# Name: 183, dtype: int64)
# (184, user_id                 222
# movie_id                 22
# rating                    5
# unix_timestamp    878183285
# Name: 184, dtype: int64)
# (185, user_id                 314
# movie_id                 28
# rating                    5
# unix_timestamp    877888346
# Name: 185, dtype: int64)
# (186, user_id                  44
# movie_id                258
# rating                    4
# unix_timestamp    878340824
# Name: 186, dtype: int64)
# (187, user_id                 125
# movie_id                318
# rating                    5
# unix_timestamp    879454309
# Name: 187, dtype: int64)
# (188, user_id                 239
# movie_id                 96
# rating                    5
# unix_timestamp    889178798
# Name: 188, dtype: int64)
# (189, user_id                 223
# movie_id                423
# rating                    3
# unix_timestamp    891550684
# Name: 189, dtype: int64)
# (190, user_id                 145
# movie_id                355
# rating                    3
# unix_timestamp    888396967
# Name: 190, dtype: int64)
# (191, user_id                  23
# movie_id                258
# rating                    5
# unix_timestamp    876785704
# Name: 191, dtype: int64)
# (192, user_id                 185
# movie_id                114
# rating                    4
# unix_timestamp    883524320
# Name: 192, dtype: int64)
# (193, user_id                 154
# movie_id                242
# rating                    3
# unix_timestamp    879138235
# Name: 193, dtype: int64)
# (194, user_id                 256
# movie_id                487
# rating                    5
# unix_timestamp    882164231
# Name: 194, dtype: int64)
# (195, user_id                 161
# movie_id                168
# rating                    1
# unix_timestamp    891171174
# Name: 195, dtype: int64)
# (196, user_id                  43
# movie_id                 40
# rating                    3
# unix_timestamp    883956468
# Name: 196, dtype: int64)
# (197, user_id                  42
# movie_id                953
# rating                    2
# unix_timestamp    881108815
# Name: 197, dtype: int64)
# (198, user_id                  56
# movie_id                869
# rating                    3
# unix_timestamp    892683895
# Name: 198, dtype: int64)
# (199, user_id                 190
# movie_id                117
# rating                    4
# unix_timestamp    891033697
# Name: 199, dtype: int64)
# (200, user_id                 303
# movie_id                779
# rating                    1
# unix_timestamp    879543418
# Name: 200, dtype: int64)
# (201, user_id                 194
# movie_id                191
# rating                    4
# unix_timestamp    879521856
# Name: 201, dtype: int64)
# (202, user_id                 110
# movie_id                568
# rating                    3
# unix_timestamp    886988449
# Name: 202, dtype: int64)
# (203, user_id                 222
# movie_id               1041
# rating                    3
# unix_timestamp    881060155
# Name: 203, dtype: int64)
# (204, user_id                 112
# movie_id                331
# rating                    4
# unix_timestamp    884992603
# Name: 204, dtype: int64)
# (205, user_id                  18
# movie_id                202
# rating                    3
# unix_timestamp    880130515
# Name: 205, dtype: int64)
# (206, user_id                 216
# movie_id                174
# rating                    5
# unix_timestamp    881432488
# Name: 206, dtype: int64)
# (207, user_id                 264
# movie_id                448
# rating                    2
# unix_timestamp    886122031
# Name: 207, dtype: int64)
# (208, user_id                 144
# movie_id                831
# rating                    3
# unix_timestamp    888104805
# Name: 208, dtype: int64)
# (209, user_id                 276
# movie_id                357
# rating                    5
# unix_timestamp    874787526
# Name: 209, dtype: int64)
# (210, user_id                 293
# movie_id                166
# rating                    3
# unix_timestamp    888905520
# Name: 210, dtype: int64)
# (211, user_id                  99
# movie_id                246
# rating                    3
# unix_timestamp    888469392
# Name: 211, dtype: int64)
# (212, user_id                 172
# movie_id                580
# rating                    4
# unix_timestamp    875538028
# Name: 212, dtype: int64)
# (213, user_id                  54
# movie_id                676
# rating                    5
# unix_timestamp    880935294
# Name: 213, dtype: int64)
# (214, user_id                 305
# movie_id                 79
# rating                    3
# unix_timestamp    886324276
# Name: 214, dtype: int64)
# (215, user_id                  82
# movie_id                343
# rating                    1
# unix_timestamp    884713755
# Name: 215, dtype: int64)
# (216, user_id                 152
# movie_id                111
# rating                    5
# unix_timestamp    880148782
# Name: 216, dtype: int64)
# (217, user_id                 244
# movie_id                662
# rating                    3
# unix_timestamp    880606533
# Name: 217, dtype: int64)
# (218, user_id                  85
# movie_id                282
# rating                    3
# unix_timestamp    879829618
# Name: 218, dtype: int64)
# (219, user_id                 279
# movie_id                 96
# rating                    4
# unix_timestamp    875310606
# Name: 219, dtype: int64)
# (220, user_id                 288
# movie_id                272
# rating                    5
# unix_timestamp    889225463
# Name: 220, dtype: int64)
# (221, user_id                  38
# movie_id                161
# rating                    5
# unix_timestamp    892432062
# Name: 221, dtype: int64)
# (222, user_id                 121
# movie_id                 14
# rating                    5
# unix_timestamp    891390014
# Name: 222, dtype: int64)
# (223, user_id                 252
# movie_id                277
# rating                    4
# unix_timestamp    891456797
# Name: 223, dtype: int64)
# (224, user_id                 117
# movie_id                 15
# rating                    5
# unix_timestamp    880125887
# Name: 224, dtype: int64)
# (225, user_id                 203
# movie_id                282
# rating                    1
# unix_timestamp    880434919
# Name: 225, dtype: int64)
# (226, user_id                  65
# movie_id               1142
# rating                    4
# unix_timestamp    879217349
# Name: 226, dtype: int64)
# (227, user_id                  76
# movie_id                175
# rating                    4
# unix_timestamp    875028853
# Name: 227, dtype: int64)
# (228, user_id                 279
# movie_id                746
# rating                    5
# unix_timestamp    875310233
# Name: 228, dtype: int64)
# (229, user_id                  13
# movie_id                121
# rating                    5
# unix_timestamp    882397503
# Name: 229, dtype: int64)
# (230, user_id                 215
# movie_id                164
# rating                    3
# unix_timestamp    891436633
# Name: 230, dtype: int64)
# (231, user_id                 161
# movie_id                898
# rating                    3
# unix_timestamp    891170191
# Name: 231, dtype: int64)
# (232, user_id                  37
# movie_id                117
# rating                    4
# unix_timestamp    880915674
# Name: 232, dtype: int64)
# (233, user_id                  70
# movie_id                 82
# rating                    4
# unix_timestamp    884068075
# Name: 233, dtype: int64)
# (234, user_id                  60
# movie_id                208
# rating                    5
# unix_timestamp    883326028
# Name: 234, dtype: int64)
# (235, user_id                 293
# movie_id                412
# rating                    1
# unix_timestamp    888905377
# Name: 235, dtype: int64)
# (236, user_id                 104
# movie_id               1010
# rating                    1
# unix_timestamp    888465554
# Name: 236, dtype: int64)
# (237, user_id                 287
# movie_id                252
# rating                    1
# unix_timestamp    875334361
# Name: 237, dtype: int64)
# (238, user_id                 145
# movie_id                764
# rating                    2
# unix_timestamp    888398257
# Name: 238, dtype: int64)
# (239, user_id                  71
# movie_id                 89
# rating                    5
# unix_timestamp    880864462
# Name: 239, dtype: int64)
# (240, user_id                 193
# movie_id                627
# rating                    4
# unix_timestamp    889126972
# Name: 240, dtype: int64)
# (241, user_id                 252
# movie_id                300
# rating                    4
# unix_timestamp    891448664
# Name: 241, dtype: int64)
# (242, user_id                 304
# movie_id                237
# rating                    5
# unix_timestamp    884968415
# Name: 242, dtype: int64)
# (243, user_id                 168
# movie_id               1278
# rating                    3
# unix_timestamp    884287560
# Name: 243, dtype: int64)
# (244, user_id                  18
# movie_id                113
# rating                    5
# unix_timestamp    880129628
# Name: 244, dtype: int64)
# (245, user_id                  51
# movie_id                182
# rating                    3
# unix_timestamp    883498790
# Name: 245, dtype: int64)
# (246, user_id                 204
# movie_id                216
# rating                    4
# unix_timestamp    892513864
# Name: 246, dtype: int64)
# (247, user_id                 294
# movie_id                282
# rating                    3
# unix_timestamp    877821796
# Name: 247, dtype: int64)
# (248, user_id                 255
# movie_id                472
# rating                    1
# unix_timestamp    883216958
# Name: 248, dtype: int64)
# (249, user_id                  90
# movie_id                507
# rating                    5
# unix_timestamp    891383987
# Name: 249, dtype: int64)
# (250, user_id                 197
# movie_id                 55
# rating                    3
# unix_timestamp    891409982
# Name: 250, dtype: int64)
# (251, user_id                 168
# movie_id                274
# rating                    4
# unix_timestamp    884287865
# Name: 251, dtype: int64)
# (252, user_id                 299
# movie_id                588
# rating                    4
# unix_timestamp    877880852
# Name: 252, dtype: int64)
# (253, user_id                  49
# movie_id                 47
# rating                    5
# unix_timestamp    888068715
# Name: 253, dtype: int64)
# (254, user_id                  92
# movie_id                216
# rating                    3
# unix_timestamp    875653867
# Name: 254, dtype: int64)
# (255, user_id                 262
# movie_id                386
# rating                    3
# unix_timestamp    879795512
# Name: 255, dtype: int64)
# (256, user_id                 222
# movie_id               1044
# rating                    4
# unix_timestamp    881060578
# Name: 256, dtype: int64)
# (257, user_id                 184
# movie_id                161
# rating                    2
# unix_timestamp    889909640
# Name: 257, dtype: int64)
# (258, user_id                 308
# movie_id                848
# rating                    4
# unix_timestamp    887736925
# Name: 258, dtype: int64)
# (259, user_id                 130
# movie_id                542
# rating                    3
# unix_timestamp    875801778
# Name: 259, dtype: int64)
# (260, user_id                 195
# movie_id                300
# rating                    3
# unix_timestamp    890588925
# Name: 260, dtype: int64)
# (261, user_id                 142
# movie_id                 82
# rating                    4
# unix_timestamp    888640356
# Name: 261, dtype: int64)
# (262, user_id                  92
# movie_id                709
# rating                    2
# unix_timestamp    875654590
# Name: 262, dtype: int64)
# (263, user_id                   3
# movie_id                337
# rating                    1
# unix_timestamp    889236983
# Name: 263, dtype: int64)
# (264, user_id                   6
# movie_id                508
# rating                    3
# unix_timestamp    883599530
# Name: 264, dtype: int64)
# (265, user_id                 293
# movie_id                132
# rating                    4
# unix_timestamp    888905481
# Name: 265, dtype: int64)
# (266, user_id                  94
# movie_id                346
# rating                    4
# unix_timestamp    891725410
# Name: 266, dtype: int64)
# (267, user_id                 291
# movie_id                 70
# rating                    4
# unix_timestamp    874868146
# Name: 267, dtype: int64)
# (268, user_id                 109
# movie_id                588
# rating                    4
# unix_timestamp    880578388
# Name: 268, dtype: int64)
# (269, user_id                 301
# movie_id                660
# rating                    4
# unix_timestamp    882076782
# Name: 269, dtype: int64)
# (270, user_id                 158
# movie_id                241
# rating                    4
# unix_timestamp    880134445
# Name: 270, dtype: int64)
# (271, user_id                 201
# movie_id                509
# rating                    3
# unix_timestamp    884111546
# Name: 271, dtype: int64)
# (272, user_id                 172
# movie_id                462
# rating                    3
# unix_timestamp    875537717
# Name: 272, dtype: int64)
# (273, user_id                 264
# movie_id                504
# rating                    5
# unix_timestamp    886122577
# Name: 273, dtype: int64)
# (274, user_id                 307
# movie_id                687
# rating                    1
# unix_timestamp    879114143
# Name: 274, dtype: int64)
# (275, user_id                 189
# movie_id                634
# rating                    3
# unix_timestamp    893265506
# Name: 275, dtype: int64)
# (276, user_id                 251
# movie_id                148
# rating                    2
# unix_timestamp    886272547
# Name: 276, dtype: int64)
# (277, user_id                  95
# movie_id                527
# rating                    4
# unix_timestamp    888954440
# Name: 277, dtype: int64)
# (278, user_id                   1
# movie_id                 17
# rating                    3
# unix_timestamp    875073198
# Name: 278, dtype: int64)
# (279, user_id                   7
# movie_id                 81
# rating                    5
# unix_timestamp    891352626
# Name: 279, dtype: int64)
# (280, user_id                  13
# movie_id                354
# rating                    2
# unix_timestamp    888779458
# Name: 280, dtype: int64)
# (281, user_id                  82
# movie_id                 14
# rating                    4
# unix_timestamp    876311280
# Name: 281, dtype: int64)
# (282, user_id                 201
# movie_id                 69
# rating                    2
# unix_timestamp    884112901
# Name: 282, dtype: int64)
# (283, user_id                 303
# movie_id                433
# rating                    4
# unix_timestamp    879467985
# Name: 283, dtype: int64)
# (284, user_id                 151
# movie_id                317
# rating                    5
# unix_timestamp    879524610
# Name: 284, dtype: int64)
# (285, user_id                 116
# movie_id                271
# rating                    4
# unix_timestamp    886310197
# Name: 285, dtype: int64)
# (286, user_id                 291
# movie_id                501
# rating                    4
# unix_timestamp    875087100
# Name: 286, dtype: int64)
# (287, user_id                 276
# movie_id                157
# rating                    5
# unix_timestamp    874790773
# Name: 287, dtype: int64)
# (288, user_id                  57
# movie_id                243
# rating                    3
# unix_timestamp    883696547
# Name: 288, dtype: int64)
# (289, user_id                 289
# movie_id                282
# rating                    3
# unix_timestamp    876789180
# Name: 289, dtype: int64)
# (290, user_id                 263
# movie_id                510
# rating                    4
# unix_timestamp    891298392
# Name: 290, dtype: int64)
# (291, user_id                 314
# movie_id                535
# rating                    4
# unix_timestamp    877887002
# Name: 291, dtype: int64)
# (292, user_id                 271
# movie_id                714
# rating                    3
# unix_timestamp    885848863
# Name: 292, dtype: int64)
# (293, user_id                  99
# movie_id                354
# rating                    2
# unix_timestamp    888469332
# Name: 293, dtype: int64)
# (294, user_id                 224
# movie_id                873
# rating                    2
# unix_timestamp    888082187
# Name: 294, dtype: int64)
# (295, user_id                  92
# movie_id                731
# rating                    4
# unix_timestamp    875653769
# Name: 295, dtype: int64)
# (296, user_id                 138
# movie_id                496
# rating                    4
# unix_timestamp    879024043
# Name: 296, dtype: int64)
# (297, user_id                 261
# movie_id                340
# rating                    5
# unix_timestamp    890454045
# Name: 297, dtype: int64)
# (298, user_id                 263
# movie_id                117
# rating                    3
# unix_timestamp    891299387
# Name: 298, dtype: int64)
# (299, user_id                 249
# movie_id                708
# rating                    4
# unix_timestamp    879572403
# Name: 299, dtype: int64)
# (300, user_id                 134
# movie_id                313
# rating                    5
# unix_timestamp    891732150
# Name: 300, dtype: int64)
# (301, user_id                 181
# movie_id               1383
# rating                    1
# unix_timestamp    878962086
# Name: 301, dtype: int64)
# (302, user_id                 247
# movie_id                736
# rating                    5
# unix_timestamp    893097024
# Name: 302, dtype: int64)
# (303, user_id                 161
# movie_id                162
# rating                    2
# unix_timestamp    891171413
# Name: 303, dtype: int64)
# (304, user_id                 177
# movie_id                209
# rating                    4
# unix_timestamp    880130736
# Name: 304, dtype: int64)
# (305, user_id                 239
# movie_id                529
# rating                    5
# unix_timestamp    889179808
# Name: 305, dtype: int64)
# (306, user_id                 261
# movie_id                875
# rating                    5
# unix_timestamp    890454351
# Name: 306, dtype: int64)
# (307, user_id                 158
# movie_id                 72
# rating                    3
# unix_timestamp    880135118
# Name: 307, dtype: int64)
# (308, user_id                 137
# movie_id                300
# rating                    5
# unix_timestamp    881432524
# Name: 308, dtype: int64)
# (309, user_id                 276
# movie_id                 38
# rating                    3
# unix_timestamp    874792574
# Name: 309, dtype: int64)
# (310, user_id                 213
# movie_id                609
# rating                    4
# unix_timestamp    878955533
# Name: 310, dtype: int64)
# (311, user_id                 305
# movie_id                189
# rating                    5
# unix_timestamp    886323303
# Name: 311, dtype: int64)
# (312, user_id                 127
# movie_id                294
# rating                    4
# unix_timestamp    884363803
# Name: 312, dtype: int64)
# (313, user_id                  45
# movie_id                473
# rating                    3
# unix_timestamp    881014417
# Name: 313, dtype: int64)
# (314, user_id                 230
# movie_id                202
# rating                    4
# unix_timestamp    880485352
# Name: 314, dtype: int64)
# (315, user_id                 123
# movie_id                531
# rating                    3
# unix_timestamp    879872671
# Name: 315, dtype: int64)
# (316, user_id                 293
# movie_id                496
# rating                    5
# unix_timestamp    888905840
# Name: 316, dtype: int64)
# (317, user_id                 303
# movie_id                435
# rating                    5
# unix_timestamp    879466491
# Name: 317, dtype: int64)
# (318, user_id                  21
# movie_id                299
# rating                    1
# unix_timestamp    874950931
# Name: 318, dtype: int64)
# (319, user_id                   5
# movie_id                376
# rating                    2
# unix_timestamp    879198045
# Name: 319, dtype: int64)
# (320, user_id                  21
# movie_id                457
# rating                    1
# unix_timestamp    874951054
# Name: 320, dtype: int64)
# (321, user_id                 147
# movie_id                292
# rating                    5
# unix_timestamp    885594040
# Name: 321, dtype: int64)
# (322, user_id                  28
# movie_id                 95
# rating                    3
# unix_timestamp    881956917
# Name: 322, dtype: int64)
# (323, user_id                 308
# movie_id                559
# rating                    4
# unix_timestamp    887740367
# Name: 323, dtype: int64)
# (324, user_id                  97
# movie_id                 89
# rating                    5
# unix_timestamp    884238939
# Name: 324, dtype: int64)
# (325, user_id                 178
# movie_id                209
# rating                    4
# unix_timestamp    882826944
# Name: 325, dtype: int64)
# (326, user_id                 109
# movie_id                101
# rating                    1
# unix_timestamp    880578186
# Name: 326, dtype: int64)
# (327, user_id                 267
# movie_id                386
# rating                    3
# unix_timestamp    878973597
# Name: 327, dtype: int64)
# (328, user_id                 244
# movie_id                409
# rating                    4
# unix_timestamp    880605294
# Name: 328, dtype: int64)
# (329, user_id                 106
# movie_id                107
# rating                    4
# unix_timestamp    883876961
# Name: 329, dtype: int64)
# (330, user_id                  67
# movie_id                 64
# rating                    5
# unix_timestamp    875379211
# Name: 330, dtype: int64)
# (331, user_id                 299
# movie_id                641
# rating                    4
# unix_timestamp    889501514
# Name: 331, dtype: int64)
# (332, user_id                 275
# movie_id                501
# rating                    3
# unix_timestamp    875154718
# Name: 332, dtype: int64)
# (333, user_id                 194
# movie_id                234
# rating                    3
# unix_timestamp    879521167
# Name: 333, dtype: int64)
# (334, user_id                 314
# movie_id                417
# rating                    4
# unix_timestamp    877888855
# Name: 334, dtype: int64)
# (335, user_id                 159
# movie_id               1037
# rating                    2
# unix_timestamp    884360502
# Name: 335, dtype: int64)
# (336, user_id                  68
# movie_id                  7
# rating                    3
# unix_timestamp    876974096
# Name: 336, dtype: int64)
# ...
# movie_id                288
# rating                    5
# unix_timestamp    891033606
# Name: 15311, dtype: int64)
# (15312, user_id                 880
# movie_id                294
# rating                    4
# unix_timestamp    880166557
# Name: 15312, dtype: int64)
# (15313, user_id                 707
# movie_id                815
# rating                    2
# unix_timestamp    880060609
# Name: 15313, dtype: int64)
# (15314, user_id                 882
# movie_id                588
# rating                    4
# unix_timestamp    879867430
# Name: 15314, dtype: int64)
# (15315, user_id                 919
# movie_id                297
# rating                    4
# unix_timestamp    875288749
# Name: 15315, dtype: int64)
# (15316, user_id                 276
# movie_id                300
# rating                    4
# unix_timestamp    874786338
# Name: 15316, dtype: int64)
# (15317, user_id                 549
# movie_id                405
# rating                    4
# unix_timestamp    881672556
# Name: 15317, dtype: int64)
# (15318, user_id                 916
# movie_id                156
# rating                    5
# unix_timestamp    880844016
# Name: 15318, dtype: int64)
# (15319, user_id                 737
# movie_id                357
# rating                    5
# unix_timestamp    884314944
# Name: 15319, dtype: int64)
# (15320, user_id                 757
# movie_id                431
# rating                    4
# unix_timestamp    888466584
# Name: 15320, dtype: int64)
# (15321, user_id                 150
# movie_id                 14
# rating                    4
# unix_timestamp    878746889
# Name: 15321, dtype: int64)
# (15322, user_id                 748
# movie_id                 96
# rating                    5
# unix_timestamp    879454662
# Name: 15322, dtype: int64)
# (15323, user_id                 294
# movie_id                342
# rating                    3
# unix_timestamp    889241466
# Name: 15323, dtype: int64)
# (15324, user_id                 908
# movie_id                318
# rating                    5
# unix_timestamp    879722717
# Name: 15324, dtype: int64)
# (15325, user_id                 402
# movie_id                410
# rating                    1
# unix_timestamp    876266985
# Name: 15325, dtype: int64)
# (15326, user_id                 853
# movie_id                261
# rating                    3
# unix_timestamp    879365360
# Name: 15326, dtype: int64)
# (15327, user_id                 637
# movie_id                508
# rating                    2
# unix_timestamp    882903301
# Name: 15327, dtype: int64)
# (15328, user_id                 497
# movie_id                182
# rating                    4
# unix_timestamp    879310705
# Name: 15328, dtype: int64)
# (15329, user_id                 429
# movie_id                409
# rating                    2
# unix_timestamp    882386751
# Name: 15329, dtype: int64)
# (15330, user_id                 932
# movie_id                 64
# rating                    2
# unix_timestamp    891250059
# Name: 15330, dtype: int64)
# (15331, user_id                 416
# movie_id                 79
# rating                    5
# unix_timestamp    893213405
# Name: 15331, dtype: int64)
# (15332, user_id                 634
# movie_id                408
# rating                    3
# unix_timestamp    875728783
# Name: 15332, dtype: int64)
# (15333, user_id                  59
# movie_id               1114
# rating                    5
# unix_timestamp    888203415
# Name: 15333, dtype: int64)
# (15334, user_id                 455
# movie_id                259
# rating                    2
# unix_timestamp    884027220
# Name: 15334, dtype: int64)
# (15335, user_id                 883
# movie_id                531
# rating                    3
# unix_timestamp    891693497
# Name: 15335, dtype: int64)
# (15336, user_id                 749
# movie_id                443
# rating                    4
# unix_timestamp    878847954
# Name: 15336, dtype: int64)
# (15337, user_id                 449
# movie_id                593
# rating                    4
# unix_timestamp    879959101
# Name: 15337, dtype: int64)
# (15338, user_id                 608
# movie_id                 92
# rating                    3
# unix_timestamp    880408150
# Name: 15338, dtype: int64)
# (15339, user_id                 782
# movie_id                271
# rating                    2
# unix_timestamp    891498213
# Name: 15339, dtype: int64)
# (15340, user_id                 486
# movie_id                252
# rating                    3
# unix_timestamp    879875316
# Name: 15340, dtype: int64)
# (15341, user_id                 911
# movie_id                420
# rating                    4
# unix_timestamp    892840950
# Name: 15341, dtype: int64)
# (15342, user_id                 708
# movie_id               1079
# rating                    1
# unix_timestamp    892719385
# Name: 15342, dtype: int64)
# (15343, user_id                 912
# movie_id                501
# rating                    4
# unix_timestamp    875966756
# Name: 15343, dtype: int64)
# (15344, user_id                 892
# movie_id                188
# rating                    5
# unix_timestamp    886608185
# Name: 15344, dtype: int64)
# (15345, user_id                 501
# movie_id                245
# rating                    3
# unix_timestamp    883346844
# Name: 15345, dtype: int64)
# (15346, user_id                 782
# movie_id                342
# rating                    2
# unix_timestamp    891498322
# Name: 15346, dtype: int64)
# (15347, user_id                 875
# movie_id               1103
# rating                    5
# unix_timestamp    876465144
# Name: 15347, dtype: int64)
# (15348, user_id                 537
# movie_id                192
# rating                    4
# unix_timestamp    886031473
# Name: 15348, dtype: int64)
# (15349, user_id                 804
# movie_id                132
# rating                    4
# unix_timestamp    879445305
# Name: 15349, dtype: int64)
# (15350, user_id                 690
# movie_id                274
# rating                    3
# unix_timestamp    881177721
# Name: 15350, dtype: int64)
# (15351, user_id                 621
# movie_id                 38
# rating                    3
# unix_timestamp    874964495
# Name: 15351, dtype: int64)
# (15352, user_id                 524
# movie_id                318
# rating                    4
# unix_timestamp    884635287
# Name: 15352, dtype: int64)
# (15353, user_id                 883
# movie_id                421
# rating                    5
# unix_timestamp    891696689
# Name: 15353, dtype: int64)
# (15354, user_id                 749
# movie_id                 50
# rating                    5
# unix_timestamp    878846978
# Name: 15354, dtype: int64)
# (15355, user_id                 270
# movie_id                265
# rating                    4
# unix_timestamp    876956137
# Name: 15355, dtype: int64)
# (15356, user_id                 654
# movie_id                405
# rating                    4
# unix_timestamp    887863866
# Name: 15356, dtype: int64)
# (15357, user_id                 928
# movie_id                328
# rating                    3
# unix_timestamp    880937258
# Name: 15357, dtype: int64)
# (15358, user_id                 566
# movie_id                462
# rating                    4
# unix_timestamp    881650090
# Name: 15358, dtype: int64)
# (15359, user_id                 870
# movie_id                943
# rating                    2
# unix_timestamp    879714310
# Name: 15359, dtype: int64)
# (15360, user_id                 847
# movie_id                685
# rating                    2
# unix_timestamp    878938922
# Name: 15360, dtype: int64)
# (15361, user_id                 465
# movie_id                408
# rating                    5
# unix_timestamp    883530391
# Name: 15361, dtype: int64)
# (15362, user_id                 871
# movie_id                904
# rating                    3
# unix_timestamp    888192858
# Name: 15362, dtype: int64)
# (15363, user_id                 934
# movie_id                419
# rating                    4
# unix_timestamp    891192849
# Name: 15363, dtype: int64)
# (15364, user_id                  59
# movie_id                273
# rating                    2
# unix_timestamp    888203129
# Name: 15364, dtype: int64)
# (15365, user_id                 798
# movie_id                443
# rating                    3
# unix_timestamp    876249370
# Name: 15365, dtype: int64)
# (15366, user_id                 773
# movie_id                895
# rating                    2
# unix_timestamp    888538417
# Name: 15366, dtype: int64)
# (15367, user_id                 271
# movie_id                169
# rating                    5
# unix_timestamp    885848475
# Name: 15367, dtype: int64)
# (15368, user_id                 918
# movie_id                747
# rating                    3
# unix_timestamp    891988705
# Name: 15368, dtype: int64)
# (15369, user_id                 588
# movie_id                265
# rating                    5
# unix_timestamp    890025621
# Name: 15369, dtype: int64)
# (15370, user_id                 913
# movie_id                 28
# rating                    3
# unix_timestamp    881369039
# Name: 15370, dtype: int64)
# (15371, user_id                 533
# movie_id                265
# rating                    3
# unix_timestamp    879191563
# Name: 15371, dtype: int64)
# (15372, user_id                 574
# movie_id                358
# rating                    2
# unix_timestamp    891279520
# Name: 15372, dtype: int64)
# (15373, user_id                 621
# movie_id                384
# rating                    3
# unix_timestamp    874963081
# Name: 15373, dtype: int64)
# (15374, user_id                  25
# movie_id                176
# rating                    4
# unix_timestamp    885852862
# Name: 15374, dtype: int64)
# (15375, user_id                 890
# movie_id                157
# rating                    4
# unix_timestamp    882916239
# Name: 15375, dtype: int64)
# (15376, user_id                 140
# movie_id                303
# rating                    5
# unix_timestamp    879013684
# Name: 15376, dtype: int64)
# (15377, user_id                 892
# movie_id                208
# rating                    4
# unix_timestamp    886609029
# Name: 15377, dtype: int64)
# (15378, user_id                 577
# movie_id                181
# rating                    5
# unix_timestamp    880474612
# Name: 15378, dtype: int64)
# (15379, user_id                 843
# movie_id                132
# rating                    3
# unix_timestamp    879446186
# Name: 15379, dtype: int64)
# (15380, user_id                 807
# movie_id                204
# rating                    4
# unix_timestamp    892528954
# Name: 15380, dtype: int64)
# (15381, user_id                 839
# movie_id               1381
# rating                    3
# unix_timestamp    875752456
# Name: 15381, dtype: int64)
# (15382, user_id                 864
# movie_id                418
# rating                    3
# unix_timestamp    888887247
# Name: 15382, dtype: int64)
# (15383, user_id                 766
# movie_id                428
# rating                    5
# unix_timestamp    891309622
# Name: 15383, dtype: int64)
# (15384, user_id                 653
# movie_id                135
# rating                    5
# unix_timestamp    878866755
# Name: 15384, dtype: int64)
# (15385, user_id                 806
# movie_id                875
# rating                    3
# unix_timestamp    882384802
# Name: 15385, dtype: int64)
# (15386, user_id                 860
# movie_id                732
# rating                    4
# unix_timestamp    885991129
# Name: 15386, dtype: int64)
# (15387, user_id                 618
# movie_id                531
# rating                    4
# unix_timestamp    891309886
# Name: 15387, dtype: int64)
# (15388, user_id                 925
# movie_id                558
# rating                    1
# unix_timestamp    884718099
# Name: 15388, dtype: int64)
# (15389, user_id                 880
# movie_id                  5
# rating                    3
# unix_timestamp    880241379
# Name: 15389, dtype: int64)
# (15390, user_id                 188
# movie_id                484
# rating                    5
# unix_timestamp    875072392
# Name: 15390, dtype: int64)
# (15391, user_id                 806
# movie_id                169
# rating                    5
# unix_timestamp    882387756
# Name: 15391, dtype: int64)
# (15392, user_id                 519
# movie_id                887
# rating                    5
# unix_timestamp    883250102
# Name: 15392, dtype: int64)
# (15393, user_id                 938
# movie_id                993
# rating                    5
# unix_timestamp    891356413
# Name: 15393, dtype: int64)
# (15394, user_id                 916
# movie_id                148
# rating                    2
# unix_timestamp    880843892
# Name: 15394, dtype: int64)
# (15395, user_id                  10
# movie_id                198
# rating                    3
# unix_timestamp    877889005
# Name: 15395, dtype: int64)
# (15396, user_id                 747
# movie_id                510
# rating                    5
# unix_timestamp    888639890
# Name: 15396, dtype: int64)
# (15397, user_id                 935
# movie_id                685
# rating                    4
# unix_timestamp    884472310
# Name: 15397, dtype: int64)
# (15398, user_id                 707
# movie_id                864
# rating                    4
# unix_timestamp    880060262
# Name: 15398, dtype: int64)
# (15399, user_id                 879
# movie_id                111
# rating                    4
# unix_timestamp    887761865
# Name: 15399, dtype: int64)
# (15400, user_id                 669
# movie_id                479
# rating                    5
# unix_timestamp    891260806
# Name: 15400, dtype: int64)
# (15401, user_id                 407
# movie_id                  7
# rating                    4
# unix_timestamp    893253637
# Name: 15401, dtype: int64)
# (15402, user_id                 887
# movie_id               1063
# rating                    1
# unix_timestamp    881380404
# Name: 15402, dtype: int64)
# (15403, user_id                 441
# movie_id                282
# rating                    4
# unix_timestamp    891035528
# Name: 15403, dtype: int64)
# (15404, user_id                 896
# movie_id                511
# rating                    5
# unix_timestamp    887158830
# Name: 15404, dtype: int64)
# (15405, user_id                 798
# movie_id                659
# rating                    4
# unix_timestamp    875914337
# Name: 15405, dtype: int64)
# (15406, user_id                 868
# movie_id                405
# rating                    1
# unix_timestamp    877109082
# Name: 15406, dtype: int64)
# (15407, user_id                 788
# movie_id                328
# rating                    4
# unix_timestamp    880867477
# Name: 15407, dtype: int64)
# (15408, user_id                 925
# movie_id                200
# rating                    2
# unix_timestamp    884717963
# Name: 15408, dtype: int64)
# (15409, user_id                 563
# movie_id                566
# rating                    4
# unix_timestamp    880507042
# Name: 15409, dtype: int64)
# (15410, user_id                 537
# movie_id                778
# rating                    3
# unix_timestamp    886031106
# Name: 15410, dtype: int64)
# (15411, user_id                 889
# movie_id                  2
# rating                    3
# unix_timestamp    880182460
# Name: 15411, dtype: int64)
# (15412, user_id                 833
# movie_id                474
# rating                    5
# unix_timestamp    875122675
# Name: 15412, dtype: int64)
# (15413, user_id                 429
# movie_id                199
# rating                    5
# unix_timestamp    882386006
# Name: 15413, dtype: int64)
# (15414, user_id                 934
# movie_id                216
# rating                    1
# unix_timestamp    891191511
# Name: 15414, dtype: int64)
# (15415, user_id                 764
# movie_id                596
# rating                    3
# unix_timestamp    876243046
# Name: 15415, dtype: int64)
# (15416, user_id                 864
# movie_id                685
# rating                    4
# unix_timestamp    888891900
# Name: 15416, dtype: int64)
# (15417, user_id                 495
# movie_id               1091
# rating                    4
# unix_timestamp    888637503
# Name: 15417, dtype: int64)
# (15418, user_id                 676
# movie_id                538
# rating                    4
# unix_timestamp    892685437
# Name: 15418, dtype: int64)
# (15419, user_id                 276
# movie_id               1090
# rating                    1
# unix_timestamp    874795795
# Name: 15419, dtype: int64)
